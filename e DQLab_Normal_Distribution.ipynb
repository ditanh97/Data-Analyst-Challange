# %% [markdown]
# # Definisi
#
# Distribusi normal merupakan fungsi probabilitas yang menunjukkan adanya distribusi atau penyebaran suatu variabel. Fungsi dari distribusi normal tersebut biasanya dibuktikan oleh adanya grafik simetris yang disebut kurva lonceng atau bell curve yang menandakan adanya distribusi yang merata, sehingga kurva akan memuncak di bagian tengah dan melandai di kedua sisi dengan nilai yang setara.

# %% [markdown]
# Variabel acak kontinu adalah variabel acak yang mempunyai nilai-nilai tak terhingga dan tak terbilang. Dimana jika X adalah variabel acak dan P(𝑋 = 𝘹) adalah distribusi probabilitas dari 𝑋, maka fungsi f(x) = P(𝑋 = 𝘹) disebut fungsi kepadatan peluang (<i>probability density function</i>).
#
# Pada distribusi normal fungsi kepadatan peluang dinyatakan sebagai berikut :
#
# \begin{equation}
# f(x)=\frac{1}{\sqrt{2\pi\sigma^2}}\:e^{-\frac{1}{2}\left(\frac{x-\mu}{\sigma}\right)^{2}},\;\;\forall\;x\:\in\:(-\infty\:,\:\infty)
# \end{equation}
#
# <b>Contoh:</b>
#
# Sebuah data berat badan mahasiswa perguruan tinggi X berdistribusi normal dengan rataan 𝜇 = 70 (kg) dengan simpangan baku σ = 3.5 (kg). Maka grafik sebaran peluangnya disajikan sebagai berikut
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Misalkan 𝑋 peubah acak kontinu yang memiliki fungsi kepadatan peluang 𝑓(𝑥).
# Fungsi distribusi kumulatif (<i>cumulative distribution function</i> / cdf) untuk peubah acak kontinu 𝑋 didefinisikan sbb:
#
# \begin{equation}
# F(x)=P(X<=x) = \int_{-\infty}^{x} f(x)\;dx, \;\;\forall\;x\:\in\:(-\infty\:,\:\infty)
# \end{equation}
#
# Dengan demikian <i>cumulative distribution function</i> dari distribusi normal adalah
#
# \begin{equation}
# F(x)=P(X<=x) = \int_{-\infty}^{x}\frac{1}{\sqrt{2\pi\sigma^2}}\:e^{-\frac{1}{2}\left(\frac{x-\mu}{\sigma}\right)^{2}}\;dx, \;\;\forall\;x\:\in\:(-\infty\:,\:\infty)
# \end{equation}
#
# Note \:
# <ol>
#   <li>Luasan dibawah kurva normal adalah 1 dengan demikian</li>
#   \begin{equation}
#   \int_{-\infty}^{\infty}\frac{1}{\sqrt{2\pi\sigma^2}}\:e^{-\frac{1}{2}\left(\frac{x-\mu}{\sigma}\right)^{2}}\;dx = 1
#   \end{equation}
#
#   <li>Kurva Normal berbentuk lonceng simetris yang artinya luasan dibawah kurva normal benar-benar membagi dua sama rata</li>
#   <img src="https://www.mathsisfun.com/data/images/normal-distribution-2.svg">
# </ol>

# %% [markdown]
# # Integral Riemann
#
# Beberapa integral dengan fungsi tertentu sangat sulit untuk dikerjakan secara eksak (hasil presisi pasti). Untuk itu digunakan pendekatan lain dalam menyelesaikan persoalan integral tertentu yakni dengan pendekatan Riemann. Pendekatan Riemann adalah salah satu aplikasi yang sangat umum untuk mengaproksimasi area dibawah grafik fungsi atau garis pada grafik, tetapi juga panjang kurva dan aproksimasi lainnya. Ide dasar integral Riemann adalah sebagai berikut
#
# Diberikan sebuah fungsi 𝑓 : \[ 𝑎 , 𝑏 \] → ℜ yang terdefinisi pada interval tertutup \[ 𝑎 , 𝑏 \] dari bilangan real. Diberikan pula
# \begin{equation}
# P = (x_0, x_1, x_2, ..., x_n)
# \end{equation}
# sebuah partisi dari \[ 𝑎 , 𝑏 \] yang mana
# \begin{equation}
# a = x_0 < x_1 < x_2 ... < x_n = b
# \end{equation}
# Sebuah jumlahan Riemann pada fungsi 𝑓 dengan partisi 𝑃 didefinsikan sebagai
# \begin{equation}
# \int_{a}^{b}f(x)\;dx = \lim_{n \to \infty}\sum_{i=0}^{n-1}f(x_i)\Delta x
# \end{equation}
#
# Dimana
# \begin{equation}
# \Delta x = \frac{b - a}{h}
# \end{equation}
#
# dengan 𝒉 = banyak partisi yang diinginkan
#
#
# Integral Riemann terbagi dalam beberapa cara pendekatan :
# <ol>
#   <li>Riemann Kiri</li>
#   <li>Riemann Tengah</li>
#   <li>Riemann Kanan</li>
# </ol>
#
# ![image.png](data:image/png;base64,...)
#
# https://en.wikipedia.org/w/index.php?title=Riemann_sum&action=edit&section=3

# %% [markdown]
# # Contoh
#
# Perusahaan DQTech merupakan perusahaan yang bergerak dibidang layanan teknologi informasi. Gaji para karyawan (<i>employee</i>) di DQTech terdistribusi secara normal dengan gaji rata-rata <span>&#36;800</span> dan standar deviasi gaji <span>&#36;50</span>. Tentukan :
# <ol>
#   <li>Peluang ditemukan karyawan dengan gaji diantara <span>&#36;750</span> sampai dengan <span>&#36;900</span></li>
#   <li>Jika terdapat 10000 karyawan pada perusahaan tersebut, tentukan banyak karyawan yang mendapatkan gaji diantara <span>&#36;750</span> sampai dengan <span>&#36;900</span> </li>
# </ol>
#
# ### Diketahui :
# *   Gaji karyawan DQTech berdistribusi normal
# *   Rata-rata gaji 𝜇 = 800
# *   Simpangan baku σ = 50
# *   Maka fungsi kepadatan peluang normalnya adalah
#
# \begin{equation}
# f(x)=\frac{1}{\sqrt{2\pi(50)^2}}\:e^{-\frac{1}{2}\left(\frac{x-800}{50}\right)^{2}},\;\;\forall\;x\:\in\:(-\infty\:,\:\infty)
# \end{equation}
#
# dengan nilai dari konstanta π = 3.14 dan 𝑒 = 2.71
#
# ### Ditanya :
#   1. Peluang ditemukan karyawan dengan gaji diantara <span>&#36;750</span> sampai dengan <span>&#36;900</span> atau
#
# \begin{equation}
# F(x)=P(750 <= x <= 900)
# \end{equation}
#
# Jawab :
# \begin{equation}
# P(750 <= x <= 900) = \int_{750}^{900}f(x)\;dx
# \end{equation}
# \begin{equation}
# P(750 <= x <= 900) = \int_{750}^{900}\frac{1}{\sqrt{2\pi(50)^2}}\:e^{-\frac{1}{2}\left(\frac{x-800}{50}\right)^{2}}\;dx
# \end{equation}
#
# Untuk menghitung integral tersebut digunakan pendekatan Riemann Tengah:
#
#
# 1.   Tentukan banyak partisi (𝑁)
#
#      Partisi yang akan digunakan pada contoh kali ini sebanyak 5, tentu anda bebas menentukan banyak partisi pada perhitungan anda. Semakin banyak partisi semakin baik nilainya
# 2.   Tentukan lebar tiap pias
# \begin{equation}
# \Delta x = \frac{b-a}{h} = \frac{900-750}{5} = 30
# \end{equation}
# 3.   Tentukan metode integral Riemann
#      Terdapat tiga tipe perhitungan integral Riemann, yakni riemann kiri, tengah ataupun kanan. Ketiga tipe ini hanya berbeda pada penentuan 𝑥 nya saja.
#      <ol>
#      <li>Riemann Kiri</li>
#         Jika digunakan metode Riemann kiri, maka 𝑥 dimulai dari batas bawah (pada kasus ini 750) lalu ditambah dengan Δ𝑥 dan seterusnya sehingga menjadi (𝑥 = 750, 780, 810, 840, 870)
#       <li>Riemann Kanan</li>
#         Jika digunakan metode Riemann kanan, maka 𝑥 dimulai dari batas bawah langsung ditambah dengan Δ𝑥 (pada kasus ni menjadi 750 + 30 = 780) dan seterusnya sehingga menjadi (𝑥 = 780, 810, 840, 870, 900)
#       <li>Riemann Tengah</li>
#         Jika digunakan metode Riemann tengah, maka 𝑥 dimulai dari batas bawah langsung ditambah dengan setengah Δ𝑥 pada awal perhitungan (pada kasus ni menjadi 750 + 30/2 = 765) untuk perhitungan selanjutnya tambahkan dengan Δ𝑥 dan seterusnya sehingga menjadi (𝑥 = 765, 795, 825, 855, 885)
#      </ol>
# 4.   Lakukan Perhitungan
#
#   Perhitungan integral riemann diilustrasikan sebagai berikut
#   ![image.png](data:image/png;base64,...)
#
# *Perhitungan selengkapnya dapat anda lihat di excel*

# %% [markdown]
# Dengan demikian diperoleh peluang ditemukan karyawan dengan gaji diantara <span>&#36;750</span> sampai dengan <span>&#36;900</span> adalah 0,8241 atau 82,41% karyawan pada DQTech berpenghasilan antara <span>&#36;750</span> sampai dengan <span>&#36;900</span>
#
# 2. Jika terdapat 10000 karyawan pada perusahaan tersebut, tentukan banyak karyawan yang mendapatkan gaji diantara diantara diantara <span>&#36;750</span> sampai dengan <span>&#36;900</span>
#
# \begin{equation}
# n = P(750<=x<=900)*10000
# \end{equation}
# \begin{equation}
# n = 0,8241*10000 = 8241\:karyawan
# \end{equation}

# %% [markdown]
# # Challenge
#
# Buatlah sebuah fungsi dengan nama `distribusi_normal(mean, stdev, batas=(a, b), jumlah_partisi)` yang akan me-<i>return</i> nilai dari fungsi kepadatan distribusi normal. Misalkan :
#
#     > mean = input('Masukan rata-rata data')
#       mean = 800
#     > stdev = input('Masukan simpangan baku data')
#       stdev = 50
#     > a = input('Masukan batas atas (a)')
#       a = 750
#     > b = input('Masukan batas bawah (b)')
#       b = 900
#     > jumlah_partisi = input('Masukan jumlah partisi')
#       jumlah_partisi = 5
#     > result = distribusi_normal(mean, stdev, batas=(a, b), jumlah_partisi)
#     > print(result)
#       0.8241

# %% [markdown]
# Dengan sintaks yang dibuat dan nilai parameter yang sama (rataan dan simpangan bakunya) gunakanlah partisi :
#
# *   jumlah_partisi = 1000
# *   jumlah_partisi = 5000
#
# Bandingkan hasilnya

# %% [markdown]
# Anda hanya diperkenankan untuk memanggil library math (contoh ada dibawah ini) dan tidak diperkenankan untuk menggunakan library statistik atau yang lainnya. Be native!

# %%
import math

# Mendapatkan nilai pi
print(math.pi)

# Mendapatkan nilai eksponensial e(x)
print(math.exp(1))

# Menghitung akar
print(math.sqrt(4))
# Out:
# 3.141592653589793
# 2.718281828459045
# 2.0

# %%
# Selamat mencoba!

mean = float(input('Masukan rata-rata data '))
# Out:
# Masukan rata-rata data 800

# %%
mean
# Out:
# 800.0

# %%
stdev = float(input('Masukan simpangan baku data '))
# Out:
# Masukan simpangan baku data 50

# %%
a = float(input('Masukan batas atas (a) '))
# Out:
# Masukan batas atas (a) 750

# %%
b = float(input('Masukan batas bawah (b) '))
# Out:
# Masukan batas bawah (b) 900

# %%
jumlah_partisi = int(input('Masukan jumlah partisi '))
# Out:
# Masukan jumlah partisi 5

# %%
def distribusi_normal(mean : float, stdev: float, batas, jumlah_partisi: int) -> float:
    print(mean, stdev, batas, jumlah_partisi)
    x_low,x_up = batas
    del_x = (float(x_up) - float(x_low)) / (jumlah_partisi)
    result = 0
    for idx_pias in range(jumlah_partisi):
        x_pias = x_low + del_x/2 
        e_term = ((x_pias-mean)/stdev)**2
        e = math.exp(-1/2*e_term)
        k = 1/(math.sqrt(math.pi*2*(stdev)**2))
        p_pias = e*k
        result += p_pias*del_x
        #update x_low with riemann kiri
        x_low += del_x
    return result

# %%
result = distribusi_normal(mean, stdev, (a, b), jumlah_partisi)
print(result)
# Out:
# 800.0 50.0 (750.0, 900.0) 5
# 0.8239038372105059

# %%
result = distribusi_normal(mean, stdev, (a, b), 1000)
print(result)
# Out:
# 800.0 50.0 (750.0, 900.0) 1000
# 0.8185947453527463

# %%
result = distribusi_normal(mean, stdev, (a, b), 5000)
print(result)
# Out:
# 800.0 50.0 (750.0, 900.0) 5000
# 0.8185946193702521

# %% [markdown]
# # Tantangan Sunnah
#
# <i>Dengan menggunakan fungsi yang anda buat, gunakan untuk menghitung persoalan berikut (partisi bebas usahakan sebesar mungkin agar meminimumkan galat yg terjadi).</i>
#
# Perusahaan DQTech merupakan perusahaan yang bergerak dibidang layanan teknologi informasi. Gaji para karyawan (<i>employee</i>) di DQTech terdistribusi secara normal dengan gaji rata-rata <span>&#36;800</span> dan standar deviasi gaji <span>&#36;50</span>. Tentukan :
# <ol>
#   <li>Peluang ditemukan karyawan dengan gaji kurang dari <span>&#36;600</span></li>
#   <li>Peluang ditemukan karyawan dengan gaji lebih dari <span>&#36;780</span></li>
#   <li>Peluang ditemukan karyawan dengan gaji diantara <span>&#36;775</span> sampai dengan <span>&#36;850</span></li>
#   <li>Jika terdapat 5000 karyawan pada perusahaan tersebut, tentukan banyak karyawan yang mendapatkan gaji diatas rata-rata</li>
# </ol>

# %%
result = distribusi_normal(800, 50, (0, 600), 5000)
print(result)
# Out:
# 800 50 (0, 600) 5000
# 3.167111335643507e-05

# %%
result = distribusi_normal(800, 50, (780, 100000), 5000)
print(result)
# Out:
# 800 50 (780, 100000) 5000
# 0.656401403587397

# %%
result = distribusi_normal(800, 50, (775, 850), 5000)
print(result)
# Out:
# 800 50 (775, 850) 5000
# 0.5328072089102225

# %%
result = distribusi_normal(800, 50, (775, 850), 5000)
print("pegawai: ",math.ceil(result*5000))
# Out:
# 800 50 (775, 850) 5000
# pegawai:  2665
